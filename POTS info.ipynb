# %%
# %pip install matplotlib pandas

import matplotlib.pyplot as plt

# POTS - Postural Orthostatic  Tachacradia  Syndrome
# Dysautonomia- dysfunction of the autonomic nervous system
# THERE IS NO CURE 
# NOT one PERSON has the SAME  repsonse to POTS that we have been made aware  (as a personal note)


# POTS - This information is very much a part of my girl's daily life. While in grade school she was very active in school plays, 
# outdoor sports, dance, and piano.

# In her second year of high school, things changed and she just thought it was a new school and harder classes, not knowing that POTS was a factor.
# We have since learned the following. Although it has changed her life, we are happy it's not as bad as some.
# 1 out of 100 people will be diagnosed with POTS

# POTS can strike any age, gender or race, but it is most often seen in women (between the ages of 15 and 50).
# Men and boys can develop it as well, but approximately 80% of patients are female.

# WHAT some people are unaware is this startling fact  25% of POTS patients cannot work or attend school! - My daughter was Valedictorian
# TIME OFF - While at home, we realized there was more to her symptoms and seeked medical attention, which proved hard to find ,
# the real answer, after telling doctors how active she had been growing up and all she did , while in school .
# There are no “cures” for POTS just “experimental medicine” that we are unwilling to try.

# Exercise and watching what she eats has proven to be her “best medicine “ practice  this far.
## NO MATTER THE Food and EXERCISE  ...SOMETIMES  on Certain  days! My daughter sleeps all day

# It highlights the significant effect that POTS can have on a person's ability to work or attend school,
# particularly emphasizing the prevalence of this impact among females.

# This information sheds light on the challenges faced by individuals with POTS and the importance of understanding 
# and managing the condition effectively.

# www.dysautonomiainternational.org

# Pie graph showing the percentage of POTS patients unable to work or attend school
labels = ['Cannot Work/Attend School', 'Can Work/Attend School']
sizes = [25, 75]
colors = ['#ff9999', '#66b3ff']
explode = (0.1, 0)  # explode the first slice

plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140, explode=explode)
plt.title('Percentage of POTS Patients Unable to Work or Attend School')
plt.axis('equal')
plt.show()










# Example data for symptoms
import pandas as pd

symptoms_data = {
	"Symptom": ["Fatigue", "Brain Fog", "Dizziness", "Palpitations"],
	"Female Percentage": [80, 70, 60, 50],
	"Male Percentage": [60, 50, 40, 30]
}
symptoms_df = pd.DataFrame(symptoms_data)

# Define x locations for the bars
x = range(len(symptoms_data["Symptom"]))
x_female = [i - 0.2 for i in x]
x_male = [i + 0.2 for i in x]

print(symptoms_df)

# Plotting the symptoms data
plt.figure(figsize=(8, 6))
plt.bar(x_female, symptoms_data["Female Percentage"], width=0.4, label="Female", color="pink")
plt.bar(x_male, symptoms_data["Male Percentage"], width=0.4, label="Male", color="blue")

# Set x-axis labels
plt.xticks([i for i in range(len(symptoms_data["Symptom"]))], symptoms_data["Symptom"], rotation=45)
plt.xlabel("Symptoms")
plt.ylabel("Percentage")
plt.title("Comparison of POTS Symptoms Between Females and Males")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#         Symptom  Female Percentage  Male Percentage
# 0       Fatigue                 80               60
# 1     Brain Fog                 70               50
# 2     Dizziness                 60               40
# 3  Palpitations                 50               30
